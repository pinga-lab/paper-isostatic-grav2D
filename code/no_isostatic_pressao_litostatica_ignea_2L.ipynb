# %% [markdown]
# # 2D Isostatic gravity inversion - Inverse Problem

# %% [markdown]
# Este [IPython Notebook](http://ipython.org/videos.html#the-ipython-notebook) utiliza a biblioteca de código aberto [Fatiando a Terra](http://fatiando.org/)

# %% [raw]
# Inversão para modelo isostático com inclusão de ignea - 2 camadas

# %%
# %matplotlib inline
import numpy as np
from scipy.misc import derivative
import scipy as spy
from scipy import interpolate
import matplotlib
#matplotlib.use('TkAgg', force=True)
import matplotlib.pyplot as plt
import math
import cPickle as pickle
import datetime
#from IPython.display import Image as img
#from IPython.display import Markdown as md
#from IPython.display import display as dp
import string as st

from scipy.misc import imread

from __future__ import division

from fatiando import gravmag, mesher, utils, gridder
from fatiando.mesher import Prism, Polygon
from fatiando.gravmag import prism
from fatiando.utils import ang2vec, si2nt, contaminate
from fatiando.gridder import regular
from fatiando.vis import mpl

from numpy.testing import assert_almost_equal
from numpy.testing import assert_array_almost_equal
from pytest import raises

plt.rc('font', size=16)
# Out:
# /Users/macelabastos/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
import functions as fc

# %% [markdown]
# ## Model parameters

# %%
# Model`s limits
ymin = 0.0
ymax = 383000.0
zmin = -1000.0
zmax = 45000.0
xmin = -100000.0
xmax = 100000.0

area = [ymin, ymax, zmax, zmin]

# %% [markdown]
# ## Prisms coordenates.

# %%
ny = 150 # number of observation datas and number of prisms along the profile
# coordinates defining the horizontal boundaries of the
# adjacent columns along the profile
y = np.linspace(ymin, ymax, ny)

# %% [markdown]
# ## Observation coordinates.

# %%
# coordinates of the center of the columns forming the
# interpretation model
n = ny - 1
dy = (ymax - ymin)/n
ycmin = ymin + 0.5*dy
ycmax = ymax - 0.5*dy
yc = np.reshape(np.linspace(ycmin, ycmax, n),(n,1))
x = np.zeros_like(yc)
z = np.zeros_like(yc)-150.0

# %%
## Edge extension (observation coordinates)
sigma = 2.0
edge = sigma*dy*n

# %% [markdown]
# ## Model parameters

# %%
# Model densities
# Indices and polygons relationship:
# cc = continental crust layer
# oc = ocean crust layer
# w = water layer
# s = sediment layer
# m = mantle layer
dw = np.array([1030.0])
ds0 = np.array([2350.0])
ds1 = np.array([2750.0])
dcc = np.array([2770.0])
doc = np.array([2865.0])
dm = np.array([3300.0])
#dc = dcc
# coordinate defining the horizontal boundaries of the continent-ocean boundary
COT = 334000.0
# list defining crust density variance
dc = np.zeros_like(yc)
aux = yc <= COT
for i in range(len(yc[aux])):
    dc[i] = dcc
for i in range(len(yc[aux]),n):
    dc[i] = doc    
# defining sediments layers density matrix
ds = np.vstack((np.reshape(np.repeat(ds0,n),(1,n)),np.reshape(np.repeat(ds1,n),(1,n))))

# S0 => isostatic compensation surface (Airy's model)
S0 = np.array([41200.0])

# %% [markdown]
# ## Surface water

# %%
tw = np.reshape(np.loadtxt('../data/noiso_pelotas_bathymetry.txt'),(n,1))

# %% [markdown]
# ## True model

# %%
true_toi = np.reshape(np.loadtxt('../data/noiso_igneous_true_toi_surface.txt'),(n,1))

# %%
true_basement = np.reshape(np.loadtxt('../data/noiso_igneous_true_basement_surface.txt'),(n,1))

# %%
true_moho = np.reshape(np.loadtxt('../data/noiso_igneous_true_moho_surface.txt'),(n,1))

# %%
# True reference moho surface (SR = S0+dS0)
true_dS0 = np.array([2500.0])

# %%
# layer sediments thickness
ts0 = true_toi - tw

# %%
# True layer sediments thickness
true_ts1 = true_basement - true_toi

# %%
# True thickness sediments vector
true_ts = np.vstack((np.reshape(ts0,(1,n)),np.reshape(true_ts1,(1,n))))

# %%
# True layer mantle thickness
true_tm = S0 - true_moho

# %%
# true parameters vector
ptrue = np.vstack((true_ts1, true_tm, true_dS0))

# %%
# synthetic data
gsyn = np.reshape(np.loadtxt('../data/noiso_igneous_synthetic_gravity_data.txt'),(n,1))

# observed data
gobs = np.reshape(np.loadtxt('../data/pelotas_gz_profile_gz.txt'),(n,1))

# %% [markdown]
# ## Known depths

# %%
# Known values: basement and moho surfaces

base_known = np.loadtxt('../data/noiso_igneous_basement_known_depths.txt')

moho_known = np.loadtxt('../data/noiso_igneous_moho_known_depths.txt')

# %% [raw]
# # Basement surface known values
# base_known = np.array([[ 8996.6442953 , 2571.60124265 ],
# [ 19278.5234899 , 2061.28734249 ],
# [ 39842.2818792 , 11564.2263147 ],
# [ 57835.5704698 , 21075.5904256 ],
# [ 86110.738255 , 26319.1369072 ],
# [ 109244.966443 , 20108.2305741 ],
# [ 132379.194631 , 12754.5239185 ],
# [ 155513.422819 , 12686.471327 ],
# [ 181218.120805 , 13168.0295398 ],
# [ 235197.986577 , 16497.3157779 ],
# [ 260902.684564 , 13800.0774904 ],
# [ 289177.852349 , 15007.7089799 ],
# [ 312312.080537 , 16034.9910351 ],
# [ 340587.248322 , 6888.23678696 ]])
#
# base_known_new = np.array([[ 19278.5234899 , 2061.28734249 ],
# [ 57835.5704698 , 21075.5904256 ],
# [ 86110.738255 , 26319.1369072 ],
# [ 132379.194631 , 12754.5239185 ],
# [ 155513.422819 , 12686.471327 ],
# [ 260902.684564 , 13664.5038426 ],
# [ 312312.080537 , 16034.9910351 ]])
#
# base_known_old = np.array([[ 8996.6442953 , 2571.60124265 ],
# [ 39842.2818792 , 11564.2263147 ],
# [ 109244.966443 , 20108.2305741 ],
# [ 181218.120805 , 13168.0295398 ],
# [ 235197.986577 , 16497.3157779 ],
# [ 289177.852349 , 15007.7089799 ],
# [ 340587.248322 , 6888.23678696 ]])

# %% [raw]
# # Moho surface known values
# moho_known = np.array([[ 70687.9194631 , 34895.8929477 ],
# [ 114385.90604 , 26366.0109691 ],
# [ 132379.194631 , 22232.019656 ],
# [ 158083.892617 , 19468.3217241 ],
# [ 194070.469799 , 22708.2693613 ],
# [ 227486.577181 , 19376.8332698 ],
# [ 268614.09396 , 21540.5029994 ],
# [ 299459.731544 , 17308.3566326 ],
# [ 330305.369128 , 17876.5353694 ]])
#
# moho_known_new = np.array([[ 70687.9194631 , 34895.8929477 ],
# [ 132379.194631 , 22232.019656 ],
# [ 227486.577181 , 19376.8332698 ],
# [ 299459.731544 , 17308.3566326 ]])
#
# moho_known_old = np.array([[ 114385.90604 , 26366.0109691 ],
# [ 158083.892617 , 19468.3217241 ],
# [ 194070.469799 , 22708.2693613 ],
# [ 268614.09396 , 21540.5029994 ],
# [ 330305.369128 , 17876.5353694 ]])

# %% [markdown]
# ## Interpretive model

# %%
# initial guess basement surface
ini_basement = np.reshape(np.loadtxt('../data/noiso_igneous_initial_basement_surface.txt'),(n,1))

# initial guess moho surface
ini_moho = np.reshape(np.loadtxt('../data/noiso_igneous_initial_moho_surface.txt'),(n,1))

# initial guess data
g0 = np.reshape(np.loadtxt('../data/noiso_igneous_initial_guess_gravity_data.txt'),(n,1))

# %% [markdown]
# # Synthetic data

# %% [markdown]
# ## Inversion model

# %%
g = np.reshape(np.loadtxt('../data/noiso_igneous_predicted_gravity_data_-11_-8_-7_-7_syn_data.txt'),(n,1))
p = np.reshape(np.loadtxt('../data/noiso_igneous_parameter_vector_-11_-8_-7_-7_syn_data.txt'),(2*n+1,1))

# %% [raw]
# ga = np.reshape(np.loadtxt('../data/noiso_igneous_predicted_gravity_data_0_0_-5_-5_syn_data.txt'),(n,1))
# pa = np.reshape(np.loadtxt('../data/noiso_igneous_parameter_vector_0_0_-5_-5_syn_data.txt'),(2*n+1,1))
# ts1a = pa[0:n]
# tma = pa[n:n+n]

# %% [raw]
# gb = np.reshape(np.loadtxt('../data/noiso_igneous_predicted_gravity_data_0_-7_-5_-5_syn_data.txt'),(n,1))
# pb = np.reshape(np.loadtxt('../data/noiso_igneous_parameter_vector_0_-7_-5_-5_syn_data.txt'),(2*n+1,1))
# ts1b = pb[0:n]
# tmb = pb[n:n+n]

# %% [raw]
# gc = np.reshape(np.loadtxt('../data/noiso_igneous_predicted_gravity_data_-15_0_-5_-5_syn_data.txt'),(n,1))
# pc = np.reshape(np.loadtxt('../data/noiso_igneous_parameter_vector_-15_0_-5_-5_syn_data.txt'),(2*n+1,1))
# ts1c = pc[0:n]
# tmc = pc[n:n+n]

# %% [raw]
# gd = np.reshape(np.loadtxt('../data/noiso_igneous_predicted_gravity_data_-14_-7_0_0_syn_data.txt'),(n,1))
# pd = np.reshape(np.loadtxt('../data/noiso_igneous_parameter_vector_-14_-7_0_0_syn_data.txt'),(2*n+1,1))
# ts1d = pd[0:n]
# tmd = pd[n:n+n]

# %%
# Inverrsion results
RM = S0 + p[n+n]
basement = tw + ts0 + p[0:n]
moho = S0 - p[n:n+n]

# %% [markdown]
# ## Lithostatic Stress

# %%
sgm_true = 9.81*(10**(-6))*(dw*tw + ds0*ts0 + ds1*true_ts1 + dc*(S0-tw-ts0-true_ts1-true_tm)+dm*true_tm)

sgm = 9.81*(10**(-6))*(dw*tw + ds0*ts0 + ds1*p[0:n] + dc*(S0-tw-ts0-p[0:n]-p[n:n+n])+dm*p[n:n+n])

#sgma = 9.81*(10**(-6))*(dw*tw + ds0*ts0 + ds1*ts1a + dc*(S0-tw-ts0-ts1a-tma)+dm*tma)

#sgmb = 9.81*(10**(-6))*(dw*tw + ds0*ts0 + ds1*ts1b + dc*(S0-tw-ts0-ts1b-tmb)+dm*tmb)

#sgmc = 9.81*(10**(-6))*(dw*tw + ds0*ts0 + ds1*ts1c + dc*(S0-tw-ts0-ts1c-tmc)+dm*tmc)

#sgmd = 9.81*(10**(-6))*(dw*tw + ds0*ts0 + ds1*ts1d + dc*(S0-tw-ts0-ts1d-tmd)+dm*tmd)

# %% [raw]
# # Normalized lithostatic stress
#
# Nsgm_true = (sgm_true - np.min(sgm_true))/(np.max(sgm_true) - np.min(sgm_true))
#
# Nsgm = (sgm - np.min(sgm))/(np.max(sgm) - np.min(sgm))
#
# #Nsgma = (sgma - np.min(sgma))/(np.max(sgma) - np.min(sgma))
#
# #Nsgmb = (sgmb - np.min(sgmb))/(np.max(sgmb) - np.min(sgmb))
#
# #Nsgmc = (sgmc - np.min(sgmc))/(np.max(sgmc) - np.min(sgmc))
#
# #Nsgmd = (sgmd - np.min(sgmd))/(np.max(sgmd) - np.min(sgmd))

# %% [markdown]
# ## Inversion model plot

# %%
polygons_water = []
for (yi, twi) in zip(yc, tw):
    y1 = yi - 0.5*dy
    y2 = yi + 0.5*dy

    polygons_water.append(Polygon(np.array([[y1, y2, y2, y1], 
                                            [0.0, 0.0, twi, twi]]).T,
                                               props={'density': dw - dcc}))
polygons_sediments0 = []
for (yi, twi, s0i) in zip(yc, np.reshape(tw,(n,)), np.reshape(true_toi,(n,))):
    y1 = yi - 0.5*dy
    y2 = yi + 0.5*dy

    polygons_sediments0.append(Polygon(np.array([[y1, y2, y2, y1], 
                                                [twi, twi, s0i, s0i]]).T,
                                                    props={'density': ds0 - dcc}))
    
polygons_sediments1 = []
for (yi, s0i, s1i) in zip(yc, np.reshape(true_toi,(n,)), np.reshape(basement,(n,))):
    y1 = yi - 0.5*dy
    y2 = yi + 0.5*dy

    polygons_sediments1.append(Polygon(np.array([[y1, y2, y2, y1], 
                                                [s0i, s0i, s1i, s1i]]).T,
                                                   props={'density': ds1 - dcc}))
    
polygons_crust = []
for (yi, si, Si, dci) in zip(yc, np.reshape(basement,(n,)), np.reshape(moho,(n,)), dc):
    y1 = yi - 0.5*dy
    y2 = yi + 0.5*dy

    polygons_crust.append(Polygon(np.array([[y1, y2, y2, y1], 
                                            [si, si, Si, Si]]).T,
                                                props={'density': dci - dcc})) 

polygons_mantle = []
for (yi, Si) in zip(yc, np.reshape(moho,(n,))):
    y1 = yi - 0.5*dy
    y2 = yi + 0.5*dy

    polygons_mantle.append(Polygon(np.array([[y1, y2, y2, y1], 
                                                [Si, Si, 50000., 50000.]]).T,
                                                    props={'density': dm - dcc}))

# %%
# %matplotlib inline
plt.close('all')
plt.figure(figsize=(12,12))

plt.subplot(3,1,1)
#plt.title('Gravity disturbance', fontsize=18)
mpl.paths([[ymin, 0.]], [[ymax, 0.]], style='--k', linewidth=1)
mpl.plot(0.001*yc, gsyn, 'or', label='simulated data')
mpl.plot(0.001*yc, g, '-g', label='predicted data')
mpl.plot(0.001*yc, g0, '-c', label='initial guess data')
#plt.ylim(-5.,70.)
plt.xlim(0.001*ymin, 0.001*ymax)
plt.ylabel('gravity disturbance (mGal)', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
mpl.tight_layout()
plt.legend(loc='best')

plt.subplot(3,1,2)
#mpl.paths([[ymin, 0.]], [[ymax, 0.]], style='--k', linewidth=1)
mpl.plot(0.001*yc, sgm_true, '-b', label='true lithostatic stress')
mpl.plot(0.001*yc, sgm, '-g', label='estimated lithostatic stress')
#mpl.plot(0.001*yc, sgma, '-g', label='normalized estimated lithostatic stress')
#mpl.plot(0.001*yc, sgmb, '-g', label='normalized estimated lithostatic stress')
#mpl.plot(0.001*yc, sgmc, '-g', label='normalized estimated lithostatic stress')
#mpl.plot(0.001*yc, sgmd, '-g', label='normalized estimated lithostatic stress')
#plt.ylim(-0.5,1.5)
plt.xlim(0.001*ymin, 0.001*ymax)
#plt.ylabel('Normalized Lithostatic Stress', fontsize=16)
plt.ylabel('Lithostatic Stress (MPa)', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
mpl.tight_layout()
plt.legend(loc='best')

plt.subplot(3,1,3)
#plt.title('Sedimentary basin', fontsize=18)

mpl.paths([[ymin, 0.0]], [[ymax, 0.0]], style='-k', linewidth=1)
aux = yc <= COT
for (pwi) in (polygons_water):
    mpl.polygon(pwi, style='-k', linewidth=1, fill='aqua')
for (ps0i) in (polygons_sediments0):
    mpl.polygon(ps0i, style='-k', linewidth=1, fill='tan')
for (ps1i) in (polygons_sediments1):
    mpl.polygon(ps1i, style='-k', linewidth=1, fill='sienna')
for (pci) in (polygons_crust[:len(yc[aux])]):
    mpl.polygon(pci, style='-k', linewidth=1, fill='orange')
for (pcoi) in (polygons_crust[len(yc[aux]):n]):
    mpl.polygon(pcoi, style='-k', linewidth=1, fill='orangered')
for (pmi) in (polygons_mantle):
    mpl.polygon(pmi, style='-k', linewidth=1, fill='plum')

mpl.plot(base_known[:,0], base_known[:,1], 'vc', linewidth=1, label='basement known values')
#mpl.plot(base_known_new[:,0], base_known_new[:,1], 'vb', linewidth=1, label='new basement known values')
#mpl.plot(base_known_old[:,0], base_known_old[:,1], 'vc', linewidth=1, label='basement known values')
mpl.plot(moho_known[:,0], moho_known[:,1], 'vg', linewidth=1, label='moho known values')
#mpl.plot(moho_known_new[:,0], moho_known_new[:,1], 'vb', linewidth=1, label='new moho known values')
#mpl.plot(moho_known_old[:,0], moho_known_old[:,1], 'vg', linewidth=1, label='moho known values')
mpl.plot(yc, true_basement, '--w', linewidth=1, label='true surfaces')
#mpl.plot(yc, true_basement, '--w', linewidth=1, label='true basement surface')
mpl.plot(yc, true_moho, '--w', linewidth=1)#, label='true moho surface')
mpl.plot(yc, ini_basement, '-.b', linewidth=1, label='initial guess surfaces')
#mpl.plot(yc, ini_basement, '-.b', linewidth=1, label='initial basement surface')
mpl.plot(yc, ini_moho, '-.b', linewidth=1)#, label='initial moho surface')
#mpl.paths([[ymin, p[n+n]]], [[ymax, p[n+n]]], style='-.r', linewidth=1, label='estimated S0 surface')
mpl.paths([[ymin, S0+p[n+n]]], [[ymax, S0+p[n+n]]], style='-.r', linewidth=1, label='estimated RM surface')
mpl.paths([[ymin, S0]], [[ymax, S0]], style='--w', linewidth=1)#, label='true S0 surface')
mpl.paths([[ymin, S0+true_dS0]], [[ymax, S0+true_dS0]], style='--w', linewidth=1)#, label='true RM')
mpl.ylim(50000., zmin)
mpl.xlim(ymin, ymax)
mpl.xlabel('y (km)', fontsize=16)
mpl.ylabel('z (km)', fontsize=16)
mpl.xticks(fontsize=14)
mpl.yticks(fontsize=14)
mpl.m2km()
mpl.tight_layout()
plt.legend(loc='lower right', fontsize='medium', facecolor='silver')

fig, ax = plt.subplots(figsize=(12,1))
plt.title('Density (kg/m$^{3}$)', fontsize=18)

cmaps_list = ['aqua','tan','sienna','orange','orangered','plum']
ncols = len(cmaps_list)
nrows = 1
dens = [dw[0], ds[0,0], ds[1,0], dcc[0], doc[0], dm[0]]

X, Y = fig.get_dpi()*fig.get_size_inches()
h = Y / nrows
w = X / (ncols + 1)
i=ncols-1
for name, name_dens in zip(cmaps_list, dens):
    col = i // nrows
    row = i % nrows
    x = X - (col*w) - w
    
    yi_line = Y - h*(row + 0.01)
    yf_line = Y - h*(row + 0.5)
    yi_text = Y - h*(row + 0.15)
    
    ax.text(x + w*0.0001, yi_text, name_dens, fontsize=(w*0.1), horizontalalignment='center', verticalalignment='top')
    ax.vlines(x + w*0.001, yi_line, yf_line, colors=name, linewidth=(w*0.7))
    i-=1
    
ax.set_xlim(0,X)
ax.set_ylim(0,Y)
ax.set_axis_off()

fig.subplots_adjust(left=0, right=1, top=1, bottom=0, hspace=0, wspace=0)

mpl.show()
#mpl.savefig('model-airy-interp_near_201_38000x4200.png', dpi=600)

# %%
# %matplotlib inline
plt.close('all')
fig = plt.figure(figsize=(12,17))
#alfa = 3.33*(17)/(12)
#fig = plt.figure(figsize=(3.33,alfa), dpi=600)

plt.subplot(4,1,1)
zeros = np.zeros_like(yc)
plt.plot(0.001*yc, zeros, '--k', linewidth=1)
plt.plot(0.001*yc, gsyn, 'ok', mfc='none', markersize=7, label='simulated data')
plt.plot(0.001*yc, g, '-k', label='predicted data')
plt.plot(0.001*yc, g0, '.k', label='initial guess data')
plt.xlim(0.001*ymin, 0.001*ymax)
plt.ylabel('gravity disturbance (mGal)', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.tight_layout()
plt.legend(loc='best', fontsize=13, facecolor='silver')

plt.subplot(4,1,2)
plt.plot(0.001*yc, sgm_true, '--k', label='true lithostatic stress')
plt.plot(0.001*yc, sgm, '-k', label='estimated lithostatic stress')
plt.xlim(0.001*ymin, 0.001*ymax)
plt.ylabel('Lithostatic Stress (MPa)', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.tight_layout()
plt.legend(loc='best', fontsize=13, facecolor='silver')        

plt.subplot(4,1,3)
plt.plot(yc, zeros, '-k', linewidth=1)
#mpl.paths([[ymin, 0.0]], [[ymax, 0.0]], style='-k', linewidth=1)
aux = yc <= COT

for (pwi) in (polygons_water):
    mpl.polygon(pwi, style='None', linewidth=0, fill='black', alpha=0.05)
for (ps0i) in (polygons_sediments0):
    mpl.polygon(ps0i, style='None', linewidth=0, fill='black', alpha=0.3)
for (ps1i) in (polygons_sediments1):
    mpl.polygon(ps1i, style='None', linewidth=0, fill='black', alpha=0.55)
for (pci) in (polygons_crust[:len(yc[aux])]):
    mpl.polygon(pci, style='None', linewidth=0, fill='black', alpha=0.67)
for (pcoi) in (polygons_crust[len(yc[aux]):n]):
    mpl.polygon(pcoi, style='None', linewidth=0, fill='black', alpha=0.78)
for (pmi) in (polygons_mantle):
    mpl.polygon(pmi, style='None', linewidth=0, fill='black')

plt.plot(yc, true_basement, '--w', linewidth=2, label='true surfaces')
plt.plot(yc, true_moho, '--w', linewidth=2)#, label='true moho surface')
plt.plot(yc, ini_basement, '-w', linewidth=2, label='initial guess surfaces')
plt.plot(yc, ini_moho, '-w', linewidth=2)#, label='initial moho surface')
plt.plot(base_known[:,0], base_known[:,1], 'vw', markersize=8.5, label='basement known values')
plt.plot(moho_known[:,0], moho_known[:,1], 'Dw', markersize=8.5, label='moho known values')
plt.ylim(50000., zmin)
plt.xlim(ymin, ymax)
plt.xlabel('y (km)', fontsize=16)
plt.ylabel('z (km)', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
mpl.m2km()
#plt.tight_layout()
plt.legend(loc='lower right', fontsize=13, facecolor='silver')

plt.subplot(4,1,4)#, frame_on=False)
X, Y = fig.get_dpi()*fig.get_size_inches()
plt.axis('off')

layers_list1 = ['water', 'sediment', 'SDR', 'continental', 'oceanic', 'mantle']
layers_list2 = ['', '', '', 'crust', 'crust', '']
alpha_list = [0.05, 0.3, 0.55, 0.67, 0.78, 1.0]
ncols = len(alpha_list)
nrows = 1
h = Y / nrows
w = X / (ncols + 1)

i=ncols-1
for alpha, layers1, layers2 in zip(alpha_list, layers_list1, layers_list2):
    col = i // nrows
    row = i % nrows
    x = X - (col*w) - w
    
    yi_line = Y
    yf_line1 = Y - Y*0.15
    yf_line2 = Y - Y*0.30
    yf_line3 = Y - Y*0.45
    yf_line4 = Y - Y*0.60
    yf_line5 = Y - Y*0.75
    yf_line6 = Y - Y*0.90
    yf_line7 = Y - Y*1.0
    yi_text1 = Y - Y*0.2
    yi_text2 = Y - Y*0.28
    
    plt.text(x+w*0.375, yi_text1, layers1, fontsize=(w*0.14), horizontalalignment='center', verticalalignment='top')
    plt.text(x+w*0.375, yi_text2, layers2, fontsize=(w*0.14), horizontalalignment='center', verticalalignment='top')
    i-=1
    poly1 = Polygon(np.array([[x, x+w*0.75, x+w*0.75, x], [yi_line, yi_line, yf_line1, yf_line1]]).T)
    poly2 = Polygon(np.array([[x, x+w*0.75, x+w*0.75, x], [yf_line1, yf_line1, yf_line2, yf_line2]]).T)
    poly3 = Polygon(np.array([[x, x+w*0.75, x+w*0.75, x], [yf_line2, yf_line2, yf_line3, yf_line3]]).T)
    poly4 = Polygon(np.array([[x, x+w*0.75, x+w*0.75, x], [yf_line3, yf_line3, yf_line4, yf_line4]]).T)
    poly5 = Polygon(np.array([[x, x+w*0.75, x+w*0.75, x], [yf_line4, yf_line4, yf_line5, yf_line5]]).T)
    poly6 = Polygon(np.array([[x, x+w*0.75, x+w*0.75, x], [yf_line5, yf_line5, yf_line6, yf_line6]]).T)
    poly7 = Polygon(np.array([[x, x+w*0.75, x+w*0.75, x], [yf_line6, yf_line6, yf_line7, yf_line7]]).T)
    mpl.polygon(poly1, style='None', linewidth=1, fill='black', alpha=alpha)
    mpl.polygon(poly2, style='None', linewidth=0, fill='white', alpha=alpha)
    mpl.polygon(poly3, style='None', linewidth=0, fill='white', alpha=alpha)
    mpl.polygon(poly4, style='None', linewidth=0, fill='white', alpha=alpha)
    mpl.polygon(poly5, style='None', linewidth=0, fill='white', alpha=alpha)
    mpl.polygon(poly6, style='None', linewidth=0, fill='white', alpha=alpha)
    mpl.polygon(poly7, style='None', linewidth=0, fill='white', alpha=alpha)
    
plt.tight_layout()

#mpl.savefig('../data/fig/model-simple_II.png', dpi='figure')
plt.show()

# %% [markdown]
# # Field data

# %% [markdown]
# ## Inversion model

# %% [raw]
# gfield = np.reshape(np.loadtxt('../data/noiso_igneous_predicted_gravity_data_-13_-8_-5_-5_field_data.txt'),(n,1))
# pfield = np.reshape(np.loadtxt('../data/noiso_igneous_parameter_vector_-13_-8_-5_-5_field_data.txt'),(2*n+1,1))

# %% [raw]
# ge = np.reshape(np.loadtxt('../data/noiso_igneous_predicted_gravity_data_0_0_-5_-5_field_data.txt'),(n,1))
# pe = np.reshape(np.loadtxt('../data/noiso_igneous_parameter_vector_0_0_-5_-5_field_data.txt'),(2*n+1,1))
# ts1e = pe[0:n]
# tme = pe[n:n+n]

# %% [raw]
# gf = np.reshape(np.loadtxt('../data/noiso_igneous_predicted_gravity_data_0_-6_-5_-5_field_data.txt'),(n,1))
# pf = np.reshape(np.loadtxt('../data/noiso_igneous_parameter_vector_0_-6_-5_-5_field_data.txt'),(2*n+1,1))
# ts1f = pf[0:n]
# tmf = pf[n:n+n]

# %% [raw]
# gh = np.reshape(np.loadtxt('../data/noiso_igneous_predicted_gravity_data_-14_0_-5_-5_field_data.txt'),(n,1))
# ph = np.reshape(np.loadtxt('../data/noiso_igneous_parameter_vector_-14_0_-5_-5_field_data.txt'),(2*n+1,1))
# ts1h = ph[0:n]
# tmh = ph[n:n+n]

# %% [raw]
# gi = np.reshape(np.loadtxt('../data/noiso_igneous_predicted_gravity_data_-13_-6_0_0_field_data.txt'),(n,1))
# pi = np.reshape(np.loadtxt('../data/noiso_igneous_parameter_vector_-13_-6_0_0_field_data.txt'),(2*n+1,1))
# ts1i = pi[0:n]
# tmi = pi[n:n+n]

# %% [raw]
# # Inverrsion results
# RM_field = S0 + pfield[n+n]
# basement_field = tw + ts0 + pfield[0:n]
# moho_field = S0 - pfield[n:n+n]

# %% [markdown]
# ## Lithostatic Stress

# %% [raw]
# sgm_true = 9.81*(10**(-6))*(dw*tw + ds0*ts0 + ds1*true_ts1 + dc*(S0-tw-ts0-true_ts1-true_tm)+dm*true_tm)
#
# sgmfield = 9.81*(10**(-6))*(dw*tw + ds0*ts0 + ds1*pfield[0:n] + dc*(S0-tw-ts0-pfield[0:n]-pfield[n:n+n])+dm*pfield[n:n+n])
#
# #sgme = 9.81*(10**(-6))*(dw*tw + ds0*ts0 + ds1*ts1e + dc*(S0-tw-ts0-ts1e-tme)+dm*tme)
#
# #sgmf = 9.81*(10**(-6))*(dw*tw + ds0*ts0 + ds1*ts1f + dc*(S0-tw-ts0-ts1f-tmf)+dm*tmf)
#
# #sgmh = 9.81*(10**(-6))*(dw*tw + ds0*ts0 + ds1*ts1h + dc*(S0-tw-ts0-ts1h-tmh)+dm*tmh)
#
# #sgmi = 9.81*(10**(-6))*(dw*tw + ds0*ts0 + ds1*ts1i + dc*(S0-tw-ts0-ts1i-tmi)+dm*tmi)

# %% [raw]
# # Normalized lithostatic stress
#
# Nsgm_true = (sgm_true - np.min(sgm_true))/(np.max(sgm_true) - np.min(sgm_true))
#
# Nsgmfield = (sgmfield - np.min(sgmfield))/(np.max(sgmfield) - np.min(sgmfield))
#
# #Nsgme = (sgme - np.min(sgme))/(np.max(sgme) - np.min(sgme))
#
# #Nsgmf = (sgmf - np.min(sgmf))/(np.max(sgmf) - np.min(sgmf))
#
# #Nsgmh = (sgmh - np.min(sgmh))/(np.max(sgmh) - np.min(sgmh))
#
# #Nsgmi = (sgmi - np.min(sgmi))/(np.max(sgmi) - np.min(sgmi))

# %% [markdown]
# ## Inversion model plot

# %% [raw]
# polygons_water = []
# for (yi, twi) in zip(yc, tw):
#     y1 = yi - 0.5*dy
#     y2 = yi + 0.5*dy
#
#     polygons_water.append(Polygon(np.array([[y1, y2, y2, y1],
#                                             [0.0, 0.0, twi, twi]]).T,
#                                                props={'density': dw - dcc}))
# polygons_sediments0 = []
# for (yi, twi, s0i) in zip(yc, np.reshape(tw,(n,)), np.reshape(true_toi,(n,))):
#     y1 = yi - 0.5*dy
#     y2 = yi + 0.5*dy
#
#     polygons_sediments0.append(Polygon(np.array([[y1, y2, y2, y1],
#                                                 [twi, twi, s0i, s0i]]).T,
#                                                     props={'density': ds0 - dcc}))
#
# polygons_sediments1 = []
# for (yi, s0i, s1i) in zip(yc, np.reshape(true_toi,(n,)), np.reshape(basement_field,(n,))):
#     y1 = yi - 0.5*dy
#     y2 = yi + 0.5*dy
#
#     polygons_sediments1.append(Polygon(np.array([[y1, y2, y2, y1],
#                                                 [s0i, s0i, s1i, s1i]]).T,
#                                                    props={'density': ds1 - dcc}))
#
# polygons_crust = []
# for (yi, si, Si, dci) in zip(yc, np.reshape(basement_field,(n,)), np.reshape(moho_field,(n,)), dc):
#     y1 = yi - 0.5*dy
#     y2 = yi + 0.5*dy
#
#     polygons_crust.append(Polygon(np.array([[y1, y2, y2, y1],
#                                             [si, si, Si, Si]]).T,
#                                                 props={'density': dci - dcc}))
#
# polygons_mantle = []
# for (yi, Si) in zip(yc, np.reshape(moho_field,(n,))):
#     y1 = yi - 0.5*dy
#     y2 = yi + 0.5*dy
#
#     polygons_mantle.append(Polygon(np.array([[y1, y2, y2, y1],
#                                                 [Si, Si, 50000., 50000.]]).T,
#                                                     props={'density': dm - dcc}))

# %% [raw]
# %matplotlib inline
# plt.close('all')
# plt.figure(figsize=(12,12))
#
# plt.subplot(3,1,1)
# #plt.title('Gravity disturbance', fontsize=18)
# mpl.paths([[ymin, 0.]], [[ymax, 0.]], style='--k', linewidth=1)
# mpl.plot(0.001*yc, gobs, 'or', label='observed data')
# mpl.plot(0.001*yc, gfield, '-g', label='predicted data')
# mpl.plot(0.001*yc, g0, '-c', label='initial guess data')
# #plt.ylim(-5.,70.)
# plt.xlim(0.001*ymin, 0.001*ymax)
# plt.ylabel('gravity disturbance (mGal)', fontsize=16)
# plt.xticks(fontsize=14)
# plt.yticks(fontsize=14)
# mpl.tight_layout()
# plt.legend(loc='best')
#
# plt.subplot(3,1,2)
# #mpl.paths([[ymin, 0.]], [[ymax, 0.]], style='--k', linewidth=1)
# mpl.plot(0.001*yc, sgm_true, '-b', label='preliminary lithostatic stress')
# mpl.plot(0.001*yc, sgmfield, '-g', label='estimated lithostatic stress')
# #mpl.plot(0.001*yc, sgma, '-g', label='normalized estimated lithostatic stress')
# #mpl.plot(0.001*yc, sgmb, '-g', label='normalized estimated lithostatic stress')
# #mpl.plot(0.001*yc, sgmc, '-g', label='normalized estimated lithostatic stress')
# #mpl.plot(0.001*yc, sgmd, '-g', label='normalized estimated lithostatic stress')
# #plt.ylim(-0.5,1.5)
# plt.xlim(0.001*ymin, 0.001*ymax)
# #plt.ylabel('Normalized Lithostatic Stress', fontsize=16)
# plt.ylabel('Lithostatic Stress (MPa)', fontsize=16)
# plt.xticks(fontsize=14)
# plt.yticks(fontsize=14)
# mpl.tight_layout()
# plt.legend(loc='best')
#
#
#
# plt.subplot(3,1,3)
# #plt.title('Sedimentary basin', fontsize=18)
#
# mpl.paths([[ymin, 0.0]], [[ymax, 0.0]], style='-k', linewidth=1)
# aux = yc <= COT
# for (pwi) in (polygons_water):
#     mpl.polygon(pwi, style='-k', linewidth=1, fill='aqua')
# for (ps0i) in (polygons_sediments0):
#     mpl.polygon(ps0i, style='-k', linewidth=1, fill='tan')
# for (ps1i) in (polygons_sediments1):
#     mpl.polygon(ps1i, style='-k', linewidth=1, fill='sienna')
# for (pci) in (polygons_crust[:len(yc[aux])]):
#     mpl.polygon(pci, style='-k', linewidth=1, fill='orange')
# for (pcoi) in (polygons_crust[len(yc[aux]):n]):
#     mpl.polygon(pcoi, style='-k', linewidth=1, fill='orangered')
# for (pmi) in (polygons_mantle):
#     mpl.polygon(pmi, style='-k', linewidth=1, fill='plum')
#
# mpl.plot(base_known[:,0], base_known[:,1], 'vc', linewidth=1, label='basement known values')
# #mpl.plot(base_known_new[:,0], base_known_new[:,1], 'vb', linewidth=1, label='new basement known values')
# #mpl.plot(base_known_old[:,0], base_known_old[:,1], 'vc', linewidth=1, label='basement known values')
# mpl.plot(moho_known[:,0], moho_known[:,1], 'vg', linewidth=1, label='moho known values')
# #mpl.plot(moho_known_new[:,0], moho_known_new[:,1], 'vb', linewidth=1, label='new moho known values')
# #mpl.plot(moho_known_old[:,0], moho_known_old[:,1], 'vg', linewidth=1, label='moho known values')
# mpl.plot(yc, true_basement, '--w', linewidth=1, label='true surfaces')
# #mpl.plot(yc, true_basement, '--w', linewidth=1, label='true basement surface')
# mpl.plot(yc, true_moho, '--w', linewidth=1)#, label='true moho surface')
# mpl.plot(yc, ini_basement, '-.b', linewidth=1, label='initial guess surfaces')
# #mpl.plot(yc, ini_basement, '-.b', linewidth=1, label='initial basement surface')
# mpl.plot(yc, ini_moho, '-.b', linewidth=1)#, label='initial moho surface')
# #mpl.paths([[ymin, pfield[n+n]]], [[ymax, pfield[n+n]]], style='-.r', linewidth=1, label='estimated S0 surface')
# mpl.paths([[ymin, S0+pfield[n+n]]], [[ymax, S0+pfield[n+n]]], style='-.r', linewidth=1, label='estimated RM surface')
# mpl.paths([[ymin, S0]], [[ymax, S0]], style='--w', linewidth=1)#, label='true S0 surface')
# mpl.paths([[ymin, S0+true_dS0]], [[ymax, S0+true_dS0]], style='--w', linewidth=1)#, label='true RM')
# mpl.ylim(50000., zmin)
# mpl.xlim(ymin, ymax)
# mpl.xlabel('y (km)', fontsize=16)
# mpl.ylabel('z (km)', fontsize=16)
# mpl.xticks(fontsize=14)
# mpl.yticks(fontsize=14)
# mpl.m2km()
# mpl.tight_layout()
# plt.legend(loc='lower right', fontsize='medium', facecolor='silver')
#
# fig, ax = plt.subplots(figsize=(12,1))
# plt.title('Density (kg/m$^{3}$)', fontsize=18)
#
# cmaps_list = ['aqua','tan','sienna','orange','orangered','plum']
# ncols = len(cmaps_list)
# nrows = 1
# dens = [dw[0], ds[0,0], ds[1,0], dcc[0], doc[0], dm[0]]
#
# X, Y = fig.get_dpi()*fig.get_size_inches()
# h = Y / nrows
# w = X / (ncols + 1)
# i=ncols-1
# for name, name_dens in zip(cmaps_list, dens):
#     col = i // nrows
#     row = i % nrows
#     x = X - (col*w) - w
#
#     yi_line = Y - h*(row + 0.01)
#     yf_line = Y - h*(row + 0.5)
#     yi_text = Y - h*(row + 0.15)
#
#     ax.text(x + w*0.0001, yi_text, name_dens, fontsize=(w*0.1), horizontalalignment='center', verticalalignment='top')
#     ax.vlines(x + w*0.001, yi_line, yf_line, colors=name, linewidth=(w*0.7))
#     i-=1
#
# ax.set_xlim(0,X)
# ax.set_ylim(0,Y)
# ax.set_axis_off()
#
# fig.subplots_adjust(left=0, right=1, top=1, bottom=0, hspace=0, wspace=0)
#
# mpl.show()
# #mpl.savefig('model-airy-interp_near_201_38000x4200.png', dpi=600)
